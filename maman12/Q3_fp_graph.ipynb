# %%
import pydot
from IPython.display import Image

# %%
# Insert { i5, i1, i4 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:1"] ;
0 -> 1 ;
2 [label="i1:1"] ;
1 -> 2 ;
4 [label="i4:1"] ;
2 -> 4 ;
}"""

graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert ‪‫{‪{ i5, i1, i2

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:2"] ;
0 -> 1 ;
2 [label="i1:2"] ;
1 -> 2 ;
4 [label="i4:1"] ;
2 -> 4 ;
5 [label="i2:1"] ;
2 -> 5 ;
}"""

graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert { i5, i1, i2, i4 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:3"] ;
0 -> 1 ;
2 [label="i1:3"] ;
1 -> 2 ;
4 [label="i4:1"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
}"""

graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert { i5, i1, i4 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:4"] ;
0 -> 1 ;
2 [label="i1:4"] ;
1 -> 2 ;
4 [label="i4:2"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;

}"""

graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert { i5, i2 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:5"] ;
0 -> 1 ;
2 [label="i1:4"] ;
1 -> 2 ;
4 [label="i4:2"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
7 [label="i2:1"] ;
1 -> 7 ;

}"""

graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert { i5, i2, i4 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:6"] ;
0 -> 1 ;
2 [label="i1:4"] ;
1 -> 2 ;
4 [label="i4:2"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
7 [label="i2:2"] ;
1 -> 7 ;
8 [label="i4:1"] ;
7 -> 8 ;

}"""


graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert { i4 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:6"] ;
0 -> 1 ;
2 [label="i1:4"] ;
1 -> 2 ;
4 [label="i4:2"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
7 [label="i2:2"] ;
1 -> 7 ;
8 [label="i4:1"] ;
7 -> 8 ;
9 [label="i4:1"] ;
0 -> 9 ;

}"""


graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Insert ‪{ i1, i2 }

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:6"] ;
0 -> 1 ;
2 [label="i1:4"] ;
1 -> 2 ;
4 [label="i4:2"] ;
2 -> 4 ;
5 [label="i2:2"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
7 [label="i2:2"] ;
1 -> 7 ;
8 [label="i4:1"] ;
7 -> 8 ;
9 [label="i4:1"] ;
0 -> 9 ;
10 [label="i1:1"] ;
0 -> 10 ;
11 [label="i2:1"] ;
10 -> 11 ;


}"""


graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

# %%
# Full Graph

# Insert { ‫{ i5, i1, i4
# Insert { ‫{ i5, i1, i2

g = """digraph Tree {
node [shape=oval] ;
0 [label="Null"] ;
1 [label="i5:8"] ;
0 -> 1 ;
2 [label="i1:6"] ;
1 -> 2 ;
4 [label="i4:3"] ;
2 -> 4 ;
5 [label="i2:3"] ;
2 -> 5 ;
6 [label="i4:1"] ;
5 -> 6 ;
7 [label="i2:2"] ;
1 -> 7 ;
8 [label="i4:1"] ;
7 -> 8 ;
9 [label="i4:1"] ;
0 -> 9 ;
10 [label="i1:1"] ;
0 -> 10 ;
11 [label="i2:1"] ;
10 -> 11 ;


}"""


graph = pydot.graph_from_dot_data(g)  
Image(graph[0].create_png())

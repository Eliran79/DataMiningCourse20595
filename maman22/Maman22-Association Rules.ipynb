# %%
import numpy as np
import pandas as pd

from pyspark.context import SparkContext
from pyspark.ml.fpm import FPGrowth
from pyspark.sql import SparkSession

# %%
# In Maman 22, our goal is to analyze the wine dataset from Maman 21.
# Since we already cleaned it on the previous project, we can reuse it.

data = pd.read_csv('winequality-white-clean.csv').drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#    FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  Chlorides  \
# 0           7.0             0.27        0.36           20.7      0.045
# 1           6.3             0.30        0.34            1.6      0.049
# 2           8.1             0.28        0.40            6.9      0.050
# 3           7.2             0.23        0.32            8.5      0.058
# 4           7.2             0.23        0.32            8.5      0.058
#
#    FreeSulfurDioxide  TotalSulfurDioxide  Density    pH  Sulphates  Alcohol  \
# 0               45.0               170.0   1.0010  3.00       0.45      8.8
# 1               14.0               132.0   0.9940  3.30       0.49      9.5
# 2               30.0                97.0   0.9951  3.26       0.44     10.1
# 3               47.0               186.0   0.9956  3.19       0.40      9.9
# 4               47.0               186.0   0.9956  3.19       0.40      9.9
#
#    Quality
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6

# %%
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (16,16), diagonal = 'kde');

# %%
# As we can see, all the features besides Quality are continuous,
# we must bin them in order to use Association Rules algorithms.
# We will bin the Quality feature as well because it is not nicely distributed
# the dataset will be transformed into quantiles for each feature.

# VolatileAcidity, ResidualSugar, Sulphates, Alcohol will divide into 4 quantiles,
# as their distribution is not mean centered, the other features will divide into 3 quantiles.
# Quality will devide same as maman 21

for c in ['VolatileAcidity', 'ResidualSugar', 'Sulphates', 'Alcohol']:
    data[c + '_bins'] = pd.qcut(data[c], 4, labels=["Low", "LowMid", "MidHigh", "High"])

for c in ['FixedAcidity', 'CitricAcid', 'Chlorides', 'FreeSulfurDioxide', 'TotalSulfurDioxide', 'Density', 'pH']:
    data[c + '_bins'] = pd.qcut(data[c], 3, labels=["Low", "Mid", "High"])

data['Quality_bins'] = pd.cut(data['Quality'], [0,5,6,10], labels=["Bad", "Mid", "Good"])
    
data = data.iloc[:,12:]
data.head()
# Out:
#   VolatileAcidity_bins ResidualSugar_bins Sulphates_bins Alcohol_bins  \
# 0              MidHigh               High         LowMid          Low
# 1              MidHigh                Low        MidHigh          Low
# 2              MidHigh            MidHigh         LowMid       LowMid
# 3               LowMid            MidHigh            Low       LowMid
# 4               LowMid            MidHigh            Low       LowMid
#
#   FixedAcidity_bins CitricAcid_bins Chlorides_bins FreeSulfurDioxide_bins  \
# 0               Mid            High            Mid                   High
# 1               Low             Mid           High                    Low
# 2              High            High           High                    Mid
# 3              High             Mid           High                   High
# 4              High             Mid           High                   High
#
#   TotalSulfurDioxide_bins Density_bins pH_bins Quality_bins
# 0                    High         High     Low          Mid
# 1                     Mid          Mid    High          Mid
# 2                     Low          Mid    High          Mid
# 3                    High         High     Mid          Mid
# 4                    High         High     Mid          Mid

# %%
# start Spark session
# prepare data to spack convention and create spark DataFrame

sc = SparkContext('local')
spark = SparkSession(sc)

data_dummies = pd.get_dummies(data)
data_spark_ready = [(i,data_dummies.columns[data_dummies.iloc[i].values==1].to_list()) for i in data.index]


df = spark.createDataFrame(data_spark_ready, ["id", "items"])

# %% [markdown]
# # PF-Growth
#
# The first model selected is FP Growth.
# It is an efficient and scalable method for mining the complete set of frequent patterns by pattern fragment growth.
# It is implemented by a data structure called FP-Tree, which represent frequent items.
#
# FP-tree construction:
#
#     Input: A transaction database DB and a minimum support threshold.
#
#     Output: FP-tree, the frequent-pattern tree of DB.
#
#     Method: The FP-tree is constructed as follows.
#         Scan the transaction database DB once.
#         Collect F, the set of frequent items, and the support of each frequent item.
#         Sort F in support-descending order as FList, the list of frequent items.
#         Create the root of an FP-tree, T, and label it as “null”.
#         For each transaction Trans in DB do the following:
#             * Select the frequent items in Trans and sort them according to the order of FList.
#               Let the sorted frequent-item list in Trans be [ p | P], where p is the first element and P is the  remaining list.
#               Call insert tree([ p | P], T ).
#             * The function insert tree([ p | P], T ) is performed as follows.
#               If T has a child N such that N.item-name = p.item-name, then increment N ’s count by 1; else create a new node N, with its count initialized to 1, its parent link linked to T, and its node-link linked to the nodes with the same item-name via the node-link structure. If P is nonempty, call insert tree(P, N ) recursively.
#
# After the construction, the tree can be mined for frequent items
# From the frequent items, we proceed to a search of meaningful once ( Like we will do with Lift value )
#
# The algorithm will provide us with a lot of rules, but some of them can be obvious or not meaningful,
# I order to reduce them, we will increase the support level, which controls how much each unique item relatively appear in the dataset.

# %%
# Build FPGrowth tree
# Remark: the project demand for min Support 0.4 brings no results, 
# so lower support was selected in order to continue with the exercise


fpGrowth = FPGrowth(itemsCol="items", minSupport=0.1, minConfidence=0.6)
model = fpGrowth.fit(df)

# %%
# Get Most interesting rules:
# In order to pick the most interesting rules, the Lift index was selected.
# Lift(A -> B) refers to the increase in the ratio of B to appeare when A is present.
# Lift(A -> B) can be calculated by dividing Confidence(A -> B) divided by Support(B).
# Mathematically it can be represented as:
# Lift(A→B) = (Confidence (A→B))/(Support (B))
# Lower lift will result in more rules that have less significant. 

FP_rules = model.associationRules.toPandas()
FP_rules[FP_rules.lift>2.5].sort_values(by=['lift'], ascending=False)  

# 36 rules of all the rules found can considered interesting and meaningfool
# Out:
#                                            antecedent  \
# 8                    [Density_bins_High, pH_bins_Low]
# 14      [ResidualSugar_bins_LowMid, Density_bins_Low]
# 80  [ResidualSugar_bins_High, Alcohol_bins_Low, To...
# 64        [ResidualSugar_bins_High, Alcohol_bins_Low]
# 21             [Density_bins_Low, Chlorides_bins_Low]
# 40  [ResidualSugar_bins_High, TotalSulfurDioxide_b...
# 26     [ResidualSugar_bins_High, Chlorides_bins_High]
# 53              [Alcohol_bins_Low, Density_bins_High]
# 19   [FreeSulfurDioxide_bins_High, Density_bins_High]
# 46  [ResidualSugar_bins_High, FreeSulfurDioxide_bi...
# 43     [Alcohol_bins_High, ResidualSugar_bins_LowMid]
# 29  [Alcohol_bins_Low, TotalSulfurDioxide_bins_Hig...
# 70  [Alcohol_bins_Low, FreeSulfurDioxide_bins_High...
# 7                    [Density_bins_High, pH_bins_Low]
# 31    [Alcohol_bins_Low, FreeSulfurDioxide_bins_High]
# 62              [Quality_bins_Bad, Density_bins_High]
# 22   [Alcohol_bins_Low, TotalSulfurDioxide_bins_High]
# 69                                [Density_bins_High]
# 49                          [ResidualSugar_bins_High]
# 5     [Density_bins_Low, TotalSulfurDioxide_bins_Low]
# 59             [ResidualSugar_bins_High, pH_bins_Low]
# 6   [ResidualSugar_bins_High, TotalSulfurDioxide_b...
# 25           [Alcohol_bins_Low, CitricAcid_bins_High]
# 44   [Alcohol_bins_High, TotalSulfurDioxide_bins_Low]
# 73           [Chlorides_bins_High, Density_bins_High]
# 2   [FreeSulfurDioxide_bins_High, TotalSulfurDioxi...
# 39  [ResidualSugar_bins_High, TotalSulfurDioxide_b...
# 36  [TotalSulfurDioxide_bins_High, Density_bins_High]
# 74          [CitricAcid_bins_High, Density_bins_High]
# 54            [Alcohol_bins_High, Chlorides_bins_Low]
# 13  [Alcohol_bins_Low, FreeSulfurDioxide_bins_High...
# 32    [Alcohol_bins_Low, FreeSulfurDioxide_bins_High]
# 17   [FreeSulfurDioxide_bins_High, Density_bins_High]
# 75                                [Alcohol_bins_High]
# 34  [TotalSulfurDioxide_bins_High, Density_bins_High]
# 71           [Chlorides_bins_High, Density_bins_High]
#
#                         consequent  confidence      lift
# 8        [ResidualSugar_bins_High]    0.816038  3.286413
# 14             [Alcohol_bins_High]    0.712644  3.011206
# 80             [Density_bins_High]    1.000000  3.003179
# 64             [Density_bins_High]    1.000000  3.003179
# 21             [Alcohol_bins_High]    0.699029  2.953679
# 40             [Density_bins_High]    0.978947  2.939954
# 26             [Density_bins_High]    0.971223  2.916756
# 53       [ResidualSugar_bins_High]    0.707340  2.848658
# 19       [ResidualSugar_bins_High]    0.705536  2.841391
# 46             [Density_bins_High]    0.938871  2.819599
# 43              [Density_bins_Low]    0.939394  2.812229
# 29       [ResidualSugar_bins_High]    0.687065  2.767005
# 70             [Density_bins_High]    0.918004  2.756929
# 7               [Alcohol_bins_Low]    0.778302  2.756146
# 31             [Density_bins_High]    0.911145  2.736330
# 62              [Alcohol_bins_Low]    0.763514  2.703776
# 22             [Density_bins_High]    0.899875  2.702485
# 69       [ResidualSugar_bins_High]    0.670057  2.698508
# 49             [Density_bins_High]    0.898551  2.698508
# 5              [Alcohol_bins_High]    0.637277  2.692751
# 59             [Density_bins_High]    0.896373  2.691968
# 6               [Alcohol_bins_Low]    0.758833  2.687200
# 25             [Density_bins_High]    0.890943  2.675660
# 44              [Density_bins_Low]    0.888025  2.658447
# 73       [ResidualSugar_bins_High]    0.658537  2.652112
# 2               [Alcohol_bins_Low]    0.744220  2.635453
# 39              [Alcohol_bins_Low]    0.742857  2.630628
# 36       [ResidualSugar_bins_High]    0.644554  2.595802
# 74              [Alcohol_bins_Low]    0.725904  2.570591
# 54              [Density_bins_Low]    0.858164  2.569055
# 13  [TotalSulfurDioxide_bins_High]    0.851240  2.564577
# 32  [TotalSulfurDioxide_bins_High]    0.844880  2.545415
# 17              [Alcohol_bins_Low]    0.712603  2.523491
# 75              [Density_bins_Low]    0.842576  2.522389
# 34              [Alcohol_bins_Low]    0.711881  2.520935
# 71              [Alcohol_bins_Low]    0.707317  2.504772

# %% [markdown]
# # Apriory
#
# The second algorithm chosen is Apriori, it is based on the apriory principle that once there is a frequent item in the dataset,
# all of his subgroups are frequent as well. for example, if [CitricAcid_bins_High, Density_bins_High] are frequent, then [CitricAcid_bins_High] and [Density_bins_High] are frequent as well.
# The algorithm is designed backword recursively, from K size items group in the set to k+1 size.
# on each step, if we don't meet the minSupport criteria, the set is chopped.
#
# It is easy to program but has a problem with big datasets, its time and space complexity are very high.

# %%
# The Apriori algorithm
# Credit: https://adataanalyst.com/machine-learning/apriori-algorithm-python-3-0/

def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1))#use frozen set so we
                            #can use it as a key in a dict    

def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData
    
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

def apriori(dataSet, minSupport = 0.5):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
data_apriori_ready = [data_dummies.columns[data_dummies.iloc[i].values==1].to_list() for i in data.index]

L,suppData = apriori(data_apriori_ready, minSupport=0.1)

# %%
suppData
# Out:
# {frozenset({'Alcohol_bins_Low'}): 0.2823878069432684,
#  frozenset({'Chlorides_bins_Mid'}): 0.31922099915325997,
#  frozenset({'CitricAcid_bins_High'}): 0.3323454699407282,
#  frozenset({'Density_bins_High'}): 0.3329805249788315,
#  frozenset({'FixedAcidity_bins_Mid'}): 0.3063082133784928,
#  frozenset({'FreeSulfurDioxide_bins_High'}): 0.3141405588484335,
#  frozenset({'Quality_bins_Mid'}): 0.4494072819644369,
#  frozenset({'ResidualSugar_bins_High'}): 0.2483065198983912,
#  frozenset({'Sulphates_bins_LowMid'}): 0.23116003386960204,
#  frozenset({'TotalSulfurDioxide_bins_High'}): 0.331922099915326,
#  frozenset({'VolatileAcidity_bins_MidHigh'}): 0.2449195596951736,
#  frozenset({'pH_bins_Low'}): 0.3389077053344623,
#  frozenset({'Chlorides_bins_High'}): 0.3196443691786621,
#  frozenset({'CitricAcid_bins_Mid'}): 0.31837425910245554,
#  frozenset({'Density_bins_Mid'}): 0.3329805249788315,
#  frozenset({'FixedAcidity_bins_Low'}): 0.3689669771380186,
#  frozenset({'FreeSulfurDioxide_bins_Low'}): 0.35076206604572396,
#  frozenset({'ResidualSugar_bins_Low'}): 0.2544453852667231,
#  frozenset({'Sulphates_bins_MidHigh'}): 0.2652413209144793,
#  frozenset({'TotalSulfurDioxide_bins_Mid'}): 0.3314987298899238,
#  frozenset({'pH_bins_High'}): 0.32726502963590176,
#  frozenset({'Alcohol_bins_LowMid'}): 0.23306519898391193,
#  frozenset({'FixedAcidity_bins_High'}): 0.3247248094834886,
#  frozenset({'FreeSulfurDioxide_bins_Mid'}): 0.33509737510584253,
#  frozenset({'ResidualSugar_bins_MidHigh'}): 0.24872988992379338,
#  frozenset({'TotalSulfurDioxide_bins_Low'}): 0.3365791701947502,
#  frozenset({'Sulphates_bins_Low'}): 0.26947502116850125,
#  frozenset({'VolatileAcidity_bins_LowMid'}): 0.24428450465707027,
#  frozenset({'pH_bins_Mid'}): 0.3338272650296359,
#  frozenset({'CitricAcid_bins_Low'}): 0.34928027095681624,
#  frozenset({'Alcohol_bins_MidHigh'}): 0.24788314987298898,
#  frozenset({'Alcohol_bins_High'}): 0.23666384419983066,
#  frozenset({'Chlorides_bins_Low'}): 0.3611346316680779,
#  frozenset({'Density_bins_Low'}): 0.334038950042337,
#  frozenset({'Quality_bins_Bad'}): 0.32832345469940727,
#  frozenset({'Sulphates_bins_High'}): 0.23412362404741743,
#  frozenset({'ResidualSugar_bins_LowMid'}): 0.2485182049110923,
#  frozenset({'VolatileAcidity_bins_Low'}): 0.27159187129551227,
#  frozenset({'Quality_bins_Good'}): 0.2222692633361558,
#  frozenset({'VolatileAcidity_bins_High'}): 0.23920406435224387,
#  frozenset({'VolatileAcidity_bins_MidHigh',
#             'pH_bins_Low'}): 0.0855207451312447,
#  frozenset({'TotalSulfurDioxide_bins_High',
#             'pH_bins_Low'}): 0.11536833192209991,
#  frozenset({'Sulphates_bins_LowMid', 'pH_bins_Low'}): 0.07811176968670618,
#  frozenset({'ResidualSugar_bins_High', 'pH_bins_Low'}): 0.12256562235393734,
#  frozenset({'Quality_bins_Mid', 'pH_bins_Low'}): 0.15389500423370026,
#  frozenset({'FreeSulfurDioxide_bins_High', 'pH_bins_Low'}): 0.1090177815410669,
#  frozenset({'FixedAcidity_bins_Mid', 'pH_bins_Low'}): 0.10922946655376799,
#  frozenset({'Density_bins_High', 'pH_bins_Low'}): 0.13463166807790009,
#  frozenset({'CitricAcid_bins_High', 'pH_bins_Low'}): 0.13209144792548688,
#  frozenset({'Chlorides_bins_Mid', 'pH_bins_Low'}): 0.10224386113463167,
#  frozenset({'Alcohol_bins_Low', 'pH_bins_Low'}): 0.12637595258255716,
#  frozenset({'TotalSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.09822184589331075,
#  frozenset({'Sulphates_bins_LowMid',
#             'VolatileAcidity_bins_MidHigh'}): 0.06138865368331922,
#  frozenset({'ResidualSugar_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.06096528365791702,
#  frozenset({'Quality_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.09970364098221846,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.0825571549534293,
#  frozenset({'FixedAcidity_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.06922099915325995,
#  frozenset({'Density_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.0855207451312447,
#  frozenset({'CitricAcid_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.0834038950042337,
#  frozenset({'Chlorides_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.07959356477561388,
#  frozenset({'Alcohol_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.07091447925486875,
#  frozenset({'Sulphates_bins_LowMid',
#             'TotalSulfurDioxide_bins_High'}): 0.081922099915326,
#  frozenset({'ResidualSugar_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.140770533446232,
#  frozenset({'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_High'}): 0.14627434377646062,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.20279424216765454,
#  frozenset({'FixedAcidity_bins_Mid',
#             'TotalSulfurDioxide_bins_High'}): 0.10414902624894158,
#  frozenset({'Density_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.21380186282811178,
#  frozenset({'CitricAcid_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.13653683319221,
#  frozenset({'Chlorides_bins_Mid',
#             'TotalSulfurDioxide_bins_High'}): 0.11875529212531753,
#  frozenset({'Alcohol_bins_Low',
#             'TotalSulfurDioxide_bins_High'}): 0.1691363251481795,
#  frozenset({'ResidualSugar_bins_High',
#             'Sulphates_bins_LowMid'}): 0.06329381879762913,
#  frozenset({'Quality_bins_Mid', 'Sulphates_bins_LowMid'}): 0.10055038103302286,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'Sulphates_bins_LowMid'}): 0.07535986452159187,
#  frozenset({'FixedAcidity_bins_Mid',
#             'Sulphates_bins_LowMid'}): 0.06668077900084673,
#  frozenset({'Density_bins_High',
#             'Sulphates_bins_LowMid'}): 0.08657917019475021,
#  frozenset({'CitricAcid_bins_High',
#             'Sulphates_bins_LowMid'}): 0.07768839966130398,
#  frozenset({'Chlorides_bins_Mid',
#             'Sulphates_bins_LowMid'}): 0.07535986452159187,
#  frozenset({'Alcohol_bins_Low', 'Sulphates_bins_LowMid'}): 0.0831922099915326,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_High'}): 0.1117696867061812,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'ResidualSugar_bins_High'}): 0.1350550381033023,
#  frozenset({'FixedAcidity_bins_Mid',
#             'ResidualSugar_bins_High'}): 0.0814987298899238,
#  frozenset({'Density_bins_High',
#             'ResidualSugar_bins_High'}): 0.2231160033869602,
#  frozenset({'CitricAcid_bins_High',
#             'ResidualSugar_bins_High'}): 0.09758679085520745,
#  frozenset({'Chlorides_bins_Mid',
#             'ResidualSugar_bins_High'}): 0.08784928027095681,
#  frozenset({'Alcohol_bins_Low',
#             'ResidualSugar_bins_High'}): 0.15707027942421675,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'Quality_bins_Mid'}): 0.14288738357324302,
#  frozenset({'FixedAcidity_bins_Mid', 'Quality_bins_Mid'}): 0.1373835732430144,
#  frozenset({'Density_bins_High', 'Quality_bins_Mid'}): 0.1452159187129551,
#  frozenset({'CitricAcid_bins_High', 'Quality_bins_Mid'}): 0.14669771380186283,
#  frozenset({'Chlorides_bins_Mid', 'Quality_bins_Mid'}): 0.15453005927180355,
#  frozenset({'Alcohol_bins_Low', 'Quality_bins_Mid'}): 0.10118543607112616,
#  frozenset({'FixedAcidity_bins_Mid',
#             'FreeSulfurDioxide_bins_High'}): 0.09652836579170194,
#  frozenset({'Density_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.17972057578323455,
#  frozenset({'CitricAcid_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.13082133784928027,
#  frozenset({'Chlorides_bins_Mid',
#             'FreeSulfurDioxide_bins_High'}): 0.11558001693480102,
#  frozenset({'Alcohol_bins_Low',
#             'FreeSulfurDioxide_bins_High'}): 0.14055884843353092,
#  frozenset({'Density_bins_High',
#             'FixedAcidity_bins_Mid'}): 0.11473327688399661,
#  frozenset({'CitricAcid_bins_High',
#             'FixedAcidity_bins_Mid'}): 0.09631668077900085,
#  frozenset({'Chlorides_bins_Mid',
#             'FixedAcidity_bins_Mid'}): 0.10393734123624047,
#  frozenset({'Alcohol_bins_Low', 'FixedAcidity_bins_Mid'}): 0.09441151566469094,
#  frozenset({'CitricAcid_bins_High', 'Density_bins_High'}): 0.14055884843353092,
#  frozenset({'Chlorides_bins_Mid', 'Density_bins_High'}): 0.11939034716342083,
#  frozenset({'Alcohol_bins_Low', 'Density_bins_High'}): 0.2220575783234547,
#  frozenset({'Chlorides_bins_Mid',
#             'CitricAcid_bins_High'}): 0.11325148179508891,
#  frozenset({'Alcohol_bins_Low', 'CitricAcid_bins_High'}): 0.11452159187129551,
#  frozenset({'Alcohol_bins_Low', 'Chlorides_bins_Mid'}): 0.09610499576629974,
#  frozenset({'TotalSulfurDioxide_bins_Mid', 'pH_bins_High'}): 0.111346316680779,
#  frozenset({'Sulphates_bins_MidHigh', 'pH_bins_High'}): 0.08107535986452159,
#  frozenset({'ResidualSugar_bins_Low', 'pH_bins_High'}): 0.10436071126164267,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.11875529212531753,
#  frozenset({'FixedAcidity_bins_Low', 'pH_bins_High'}): 0.18162574089754446,
#  frozenset({'Density_bins_Mid', 'pH_bins_High'}): 0.11854360711261643,
#  frozenset({'CitricAcid_bins_Mid', 'pH_bins_High'}): 0.11833192209991533,
#  frozenset({'Chlorides_bins_High', 'pH_bins_High'}): 0.09271803556308214,
#  frozenset({'VolatileAcidity_bins_MidHigh',
#             'pH_bins_High'}): 0.07006773920406435,
#  frozenset({'Quality_bins_Mid', 'pH_bins_High'}): 0.14754445385266723,
#  frozenset({'Alcohol_bins_Low', 'pH_bins_High'}): 0.05779000846740051,
#  frozenset({'Sulphates_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Mid'}): 0.07959356477561388,
#  frozenset({'ResidualSugar_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.08869602032176122,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10076206604572396,
#  frozenset({'FixedAcidity_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.12933954276037257,
#  frozenset({'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.13166807790008467,
#  frozenset({'CitricAcid_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10922946655376799,
#  frozenset({'Chlorides_bins_High',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10457239627434378,
#  frozenset({'TotalSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.07832345469940728,
#  frozenset({'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.14585097375105843,
#  frozenset({'Alcohol_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.07535986452159187,
#  frozenset({'ResidualSugar_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.06181202370872142,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.09017781541066892,
#  frozenset({'FixedAcidity_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.09674005080440305,
#  frozenset({'Density_bins_Mid', 'Sulphates_bins_MidHigh'}): 0.0846740050804403,
#  frozenset({'CitricAcid_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.0827688399661304,
#  frozenset({'Chlorides_bins_High',
#             'Sulphates_bins_MidHigh'}): 0.10203217612193057,
#  frozenset({'Sulphates_bins_MidHigh',
#             'VolatileAcidity_bins_MidHigh'}): 0.06138865368331922,
#  frozenset({'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.12108382726502964,
#  frozenset({'Alcohol_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.09060118543607112,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.12912785774767147,
#  frozenset({'FixedAcidity_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.10711261642675698,
#  frozenset({'Density_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.09652836579170194,
#  frozenset({'CitricAcid_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.08890770533446232,
#  frozenset({'Chlorides_bins_High',
#             'ResidualSugar_bins_Low'}): 0.06138865368331922,
#  frozenset({'ResidualSugar_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.05292125317527519,
#  frozenset({'Quality_bins_Mid', 'ResidualSugar_bins_Low'}): 0.1138865368331922,
#  frozenset({'Alcohol_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.029212531752751906,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.13166807790008467,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Low'}): 0.14944961896697714,
#  frozenset({'CitricAcid_bins_Mid',
#             'FreeSulfurDioxide_bins_Low'}): 0.11600338696020322,
#  frozenset({'Chlorides_bins_High',
#             'FreeSulfurDioxide_bins_Low'}): 0.10097375105842506,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.0823454699407282,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid'}): 0.15220152413209145,
#  frozenset({'Alcohol_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.06498729889923793,
#  frozenset({'Density_bins_Mid', 'FixedAcidity_bins_Low'}): 0.12298899237933954,
#  frozenset({'CitricAcid_bins_Mid',
#             'FixedAcidity_bins_Low'}): 0.10436071126164267,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_Low'}): 0.10033869602032176,
#  frozenset({'FixedAcidity_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.09546994072819644,
#  frozenset({'FixedAcidity_bins_Low', 'Quality_bins_Mid'}): 0.1691363251481795,
#  frozenset({'Alcohol_bins_Low', 'FixedAcidity_bins_Low'}): 0.09144792548687553,
#  frozenset({'CitricAcid_bins_Mid', 'Density_bins_Mid'}): 0.10182049110922947,
#  frozenset({'Chlorides_bins_High', 'Density_bins_Mid'}): 0.11685012701100762,
#  frozenset({'Density_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.08065198983911939,
#  frozenset({'Density_bins_Mid', 'Quality_bins_Mid'}): 0.15262489415749364,
#  frozenset({'Alcohol_bins_Low', 'Density_bins_Mid'}): 0.05990685859441151,
#  frozenset({'Chlorides_bins_High',
#             'CitricAcid_bins_Mid'}): 0.08742591024555461,
#  frozenset({'CitricAcid_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.07578323454699407,
#  frozenset({'CitricAcid_bins_Mid', 'Quality_bins_Mid'}): 0.15220152413209145,
#  frozenset({'Alcohol_bins_Low', 'CitricAcid_bins_Mid'}): 0.057578323454699404,
#  frozenset({'Chlorides_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.07472480948348857,
#  frozenset({'Chlorides_bins_High', 'Quality_bins_Mid'}): 0.13272650296359018,
#  frozenset({'Alcohol_bins_Low', 'Chlorides_bins_High'}): 0.15982218458933106,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Low'}): 0.06160033869602032,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.10922946655376799,
#  frozenset({'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.09843353090601185,
#  frozenset({'Alcohol_bins_LowMid',
#             'TotalSulfurDioxide_bins_Low'}): 0.05800169348010161,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.11685012701100762,
#  frozenset({'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.11367485182049111,
#  frozenset({'Chlorides_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.05800169348010161,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.06837425910245555,
#  frozenset({'Sulphates_bins_LowMid',
#             'TotalSulfurDioxide_bins_Low'}): 0.07049110922946655,
#  frozenset({'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.15728196443691786,
#  frozenset({'CitricAcid_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.09377646062658763,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.08573243014394581,
#  frozenset({'FixedAcidity_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.07006773920406435,
#  frozenset({'Alcohol_bins_LowMid',
#             'ResidualSugar_bins_MidHigh'}): 0.07345469940728197,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'pH_bins_High'}): 0.07154953429297206,
#  frozenset({'Density_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.11917866215071973,
#  frozenset({'Chlorides_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.0827688399661304,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'VolatileAcidity_bins_MidHigh'}): 0.06795088907705335,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'Sulphates_bins_LowMid'}): 0.0552497883149873,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.11579170194750212,
#  frozenset({'CitricAcid_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.0842506350550381,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Mid'}): 0.10033869602032176,
#  frozenset({'Alcohol_bins_LowMid',
#             'FreeSulfurDioxide_bins_Mid'}): 0.07324301439458086,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.11917866215071973,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid'}): 0.10711261642675698,
#  frozenset({'Chlorides_bins_High',
#             'FreeSulfurDioxide_bins_Mid'}): 0.09674005080440305,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_MidHigh'}): 0.08001693480101608,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Sulphates_bins_LowMid'}): 0.07917019475021168,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Mid'}): 0.15431837425910244,
#  frozenset({'CitricAcid_bins_High',
#             'FreeSulfurDioxide_bins_Mid'}): 0.09674005080440305,
#  frozenset({'Alcohol_bins_LowMid',
#             'FixedAcidity_bins_High'}): 0.08488569009314141,
#  frozenset({'FixedAcidity_bins_High', 'pH_bins_High'}): 0.0556731583403895,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High'}): 0.11473327688399661,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_High'}): 0.12171888230313294,
#  frozenset({'FixedAcidity_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.08022861981371719,
#  frozenset({'FixedAcidity_bins_High',
#             'Sulphates_bins_LowMid'}): 0.07620660457239628,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Mid'}): 0.14288738357324302,
#  frozenset({'CitricAcid_bins_High',
#             'FixedAcidity_bins_High'}): 0.15071972904318373,
#  frozenset({'Alcohol_bins_LowMid', 'pH_bins_High'}): 0.09271803556308214,
#  frozenset({'Alcohol_bins_LowMid', 'Density_bins_Mid'}): 0.12531752751905165,
#  frozenset({'Alcohol_bins_LowMid',
#             'Chlorides_bins_High'}): 0.09483488569009314,
#  frozenset({'Alcohol_bins_LowMid',
#             'VolatileAcidity_bins_MidHigh'}): 0.0548264182895851,
#  frozenset({'Alcohol_bins_LowMid',
#             'Sulphates_bins_LowMid'}): 0.04911092294665537,
#  frozenset({'Alcohol_bins_LowMid', 'Quality_bins_Mid'}): 0.11833192209991533,
#  frozenset({'Alcohol_bins_LowMid',
#             'CitricAcid_bins_High'}): 0.07324301439458086,
#  frozenset({'Sulphates_bins_LowMid', 'pH_bins_High'}): 0.07133784928027095,
#  frozenset({'CitricAcid_bins_High', 'pH_bins_High'}): 0.0855207451312447,
#  frozenset({'Density_bins_Mid', 'Sulphates_bins_LowMid'}): 0.07197290431837426,
#  frozenset({'CitricAcid_bins_High', 'Density_bins_Mid'}): 0.09674005080440305,
#  frozenset({'Chlorides_bins_High',
#             'Sulphates_bins_LowMid'}): 0.08848433530906012,
#  frozenset({'Chlorides_bins_High',
#             'CitricAcid_bins_High'}): 0.1104995766299746,
#  frozenset({'VolatileAcidity_bins_LowMid',
#             'pH_bins_Mid'}): 0.08530906011854361,
#  frozenset({'Sulphates_bins_Low', 'pH_bins_Mid'}): 0.09060118543607112,
#  frozenset({'ResidualSugar_bins_MidHigh', 'pH_bins_Mid'}): 0.10245554614733277,
#  frozenset({'FixedAcidity_bins_High', 'pH_bins_Mid'}): 0.09758679085520745,
#  frozenset({'Alcohol_bins_LowMid', 'pH_bins_Mid'}): 0.0831922099915326,
#  frozenset({'CitricAcid_bins_Mid', 'pH_bins_Mid'}): 0.09885690093141405,
#  frozenset({'Chlorides_bins_High', 'pH_bins_Mid'}): 0.11452159187129551,
#  frozenset({'TotalSulfurDioxide_bins_High',
#             'pH_bins_Mid'}): 0.11748518204911092,
#  frozenset({'Quality_bins_Mid', 'pH_bins_Mid'}): 0.14796782387806942,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'pH_bins_Mid'}): 0.11579170194750212,
#  frozenset({'Density_bins_High', 'pH_bins_Mid'}): 0.1143099068585944,
#  frozenset({'Sulphates_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.06519898391193904,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'VolatileAcidity_bins_LowMid'}): 0.05948348856900931,
#  frozenset({'FixedAcidity_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.07938187976291279,
#  frozenset({'Alcohol_bins_LowMid',
#             'VolatileAcidity_bins_LowMid'}): 0.05821337849280271,
#  frozenset({'CitricAcid_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.08784928027095681,
#  frozenset({'Chlorides_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.0823454699407282,
#  frozenset({'TotalSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.08763759525825572,
#  frozenset({'Quality_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.12404741744284505,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.09123624047417443,
#  frozenset({'Density_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.09737510584250635,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'Sulphates_bins_Low'}): 0.07557154953429297,
#  frozenset({'FixedAcidity_bins_High',
#             'Sulphates_bins_Low'}): 0.09589331075359865,
#  frozenset({'Alcohol_bins_LowMid', 'Sulphates_bins_Low'}): 0.04593564775613886,
#  frozenset({'CitricAcid_bins_Mid', 'Sulphates_bins_Low'}): 0.08742591024555461,
#  frozenset({'Chlorides_bins_High', 'Sulphates_bins_Low'}): 0.06244707874682472,
#  frozenset({'Sulphates_bins_Low',
#             'TotalSulfurDioxide_bins_High'}): 0.05228619813717189,
#  frozenset({'Quality_bins_Mid', 'Sulphates_bins_Low'}): 0.11854360711261643,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'Sulphates_bins_Low'}): 0.07535986452159187,
#  frozenset({'Density_bins_High', 'Sulphates_bins_Low'}): 0.06392887383573242,
#  frozenset({'CitricAcid_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.07366638441998306,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'TotalSulfurDioxide_bins_High'}): 0.1107112616426757,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.09483488569009314,
#  frozenset({'Density_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.09801016088060965,
#  frozenset({'CitricAcid_bins_Mid',
#             'FixedAcidity_bins_High'}): 0.10055038103302286,
#  frozenset({'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.12912785774767147,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.10287891617273497,
#  frozenset({'Density_bins_High',
#             'FixedAcidity_bins_High'}): 0.1359017781541067,
#  frozenset({'Alcohol_bins_LowMid',
#             'CitricAcid_bins_Mid'}): 0.07366638441998306,
#  frozenset({'Alcohol_bins_LowMid',
#             'TotalSulfurDioxide_bins_High'}): 0.09144792548687553,
#  frozenset({'Alcohol_bins_LowMid',
#             'FreeSulfurDioxide_bins_High'}): 0.07811176968670618,
#  frozenset({'Alcohol_bins_LowMid', 'Density_bins_High'}): 0.08827265029635901,
#  frozenset({'CitricAcid_bins_Mid',
#             'TotalSulfurDioxide_bins_High'}): 0.09102455546147332,
#  frozenset({'CitricAcid_bins_Mid',
#             'FreeSulfurDioxide_bins_High'}): 0.0821337849280271,
#  frozenset({'CitricAcid_bins_Mid', 'Density_bins_High'}): 0.0842506350550381,
#  frozenset({'Chlorides_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.15707027942421675,
#  frozenset({'Chlorides_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.12193056731583404,
#  frozenset({'Chlorides_bins_High', 'Density_bins_High'}): 0.1735817104149026,
#  frozenset({'CitricAcid_bins_Low', 'pH_bins_Mid'}): 0.12023708721422523,
#  frozenset({'CitricAcid_bins_Low',
#             'ResidualSugar_bins_MidHigh'}): 0.09081287044877223,
#  frozenset({'CitricAcid_bins_Low',
#             'FreeSulfurDioxide_bins_Mid'}): 0.11812023708721422,
#  frozenset({'Alcohol_bins_LowMid',
#             'CitricAcid_bins_Low'}): 0.08615580016934801,
#  frozenset({'CitricAcid_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.12023708721422523,
#  frozenset({'CitricAcid_bins_Low',
#             'FixedAcidity_bins_Low'}): 0.17929720575783234,
#  frozenset({'CitricAcid_bins_Low', 'Density_bins_Mid'}): 0.13441998306519898,
#  frozenset({'CitricAcid_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.08573243014394581,
#  frozenset({'CitricAcid_bins_Low',
#             'Sulphates_bins_LowMid'}): 0.0859441151566469,
#  frozenset({'CitricAcid_bins_Low', 'Quality_bins_Mid'}): 0.15050804403048265,
#  frozenset({'Chlorides_bins_Mid', 'CitricAcid_bins_Low'}): 0.10817104149026249,
#  frozenset({'FreeSulfurDioxide_bins_Mid', 'pH_bins_Mid'}): 0.1121930567315834,
#  frozenset({'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_Mid'}): 0.11600338696020322,
#  frozenset({'FixedAcidity_bins_Low', 'pH_bins_Mid'}): 0.12912785774767147,
#  frozenset({'Density_bins_Mid', 'pH_bins_Mid'}): 0.1143099068585944,
#  frozenset({'VolatileAcidity_bins_MidHigh',
#             'pH_bins_Mid'}): 0.08933107535986452,
#  frozenset({'Sulphates_bins_LowMid', 'pH_bins_Mid'}): 0.0817104149026249,
#  frozenset({'Chlorides_bins_Mid', 'pH_bins_Mid'}): 0.1138865368331922,
#  frozenset({'ResidualSugar_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Mid'}): 0.07641828958509737,
#  frozenset({'FixedAcidity_bins_Low',
#             'ResidualSugar_bins_MidHigh'}): 0.08911939034716342,
#  frozenset({'Chlorides_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.07895850973751059,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.1367485182049111,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Mid'}): 0.12256562235393734,
#  frozenset({'Chlorides_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid'}): 0.10732430143945809,
#  frozenset({'Alcohol_bins_LowMid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.0836155800169348,
#  frozenset({'Alcohol_bins_LowMid',
#             'FixedAcidity_bins_Low'}): 0.08044030482641829,
#  frozenset({'Alcohol_bins_LowMid', 'Chlorides_bins_Mid'}): 0.08996613039796783,
#  frozenset({'Sulphates_bins_LowMid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.07874682472480948,
#  frozenset({'Chlorides_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10732430143945809,
#  frozenset({'FixedAcidity_bins_Low',
#             'Sulphates_bins_LowMid'}): 0.08827265029635901,
#  frozenset({'Chlorides_bins_Mid',
#             'FixedAcidity_bins_Low'}): 0.11621507197290432,
#  frozenset({'Chlorides_bins_Mid', 'Density_bins_Mid'}): 0.1130397967823878,
#  frozenset({'Alcohol_bins_MidHigh', 'pH_bins_Mid'}): 0.07790008467400508,
#  frozenset({'Alcohol_bins_MidHigh',
#             'VolatileAcidity_bins_LowMid'}): 0.06308213378492802,
#  frozenset({'Alcohol_bins_MidHigh',
#             'FreeSulfurDioxide_bins_Mid'}): 0.08763759525825572,
#  frozenset({'Alcohol_bins_MidHigh',
#             'FixedAcidity_bins_High'}): 0.0834038950042337,
#  frozenset({'Alcohol_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Mid'}): 0.09462320067739204,
#  frozenset({'Alcohol_bins_MidHigh',
#             'ResidualSugar_bins_Low'}): 0.09801016088060965,
#  frozenset({'Alcohol_bins_MidHigh', 'Density_bins_Mid'}): 0.1121930567315834,
#  frozenset({'Alcohol_bins_MidHigh',
#             'Sulphates_bins_LowMid'}): 0.051862828111769683,
#  frozenset({'Alcohol_bins_MidHigh', 'Quality_bins_Mid'}): 0.12616426756985605,
#  frozenset({'Alcohol_bins_MidHigh',
#             'CitricAcid_bins_High'}): 0.07620660457239628,
#  frozenset({'Alcohol_bins_MidHigh',
#             'Chlorides_bins_Mid'}): 0.08933107535986452,
#  frozenset({'ResidualSugar_bins_Low', 'pH_bins_Mid'}): 0.07747671464860288,
#  frozenset({'CitricAcid_bins_High', 'pH_bins_Mid'}): 0.11473327688399661,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.0846740050804403,
#  frozenset({'TotalSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.0834038950042337,
#  frozenset({'ResidualSugar_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.05397967823878069,
#  frozenset({'Density_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.07684165961049957,
#  frozenset({'Sulphates_bins_LowMid',
#             'VolatileAcidity_bins_LowMid'}): 0.05779000846740051,
#  frozenset({'CitricAcid_bins_High',
#             'VolatileAcidity_bins_LowMid'}): 0.0825571549534293,
#  frozenset({'Chlorides_bins_Mid',
#             'VolatileAcidity_bins_LowMid'}): 0.0836155800169348,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.0825571549534293,
#  frozenset({'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_Mid'}): 0.09716342082980525,
#  frozenset({'FixedAcidity_bins_High',
#             'ResidualSugar_bins_Low'}): 0.08488569009314141,
#  frozenset({'Chlorides_bins_Mid',
#             'FixedAcidity_bins_High'}): 0.09906858594411516,
#  frozenset({'CitricAcid_bins_High',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10203217612193057,
#  frozenset({'ResidualSugar_bins_Low',
#             'Sulphates_bins_LowMid'}): 0.05990685859441151,
#  frozenset({'CitricAcid_bins_High',
#             'ResidualSugar_bins_Low'}): 0.0859441151566469,
#  frozenset({'Chlorides_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.08086367485182049,
#  frozenset({'Quality_bins_Bad', 'Sulphates_bins_High'}): 0.05969517358171041,
#  frozenset({'Density_bins_Low', 'Sulphates_bins_High'}): 0.0817104149026249,
#  frozenset({'Chlorides_bins_Low', 'Sulphates_bins_High'}): 0.0829805249788315,
#  frozenset({'Alcohol_bins_High', 'Sulphates_bins_High'}): 0.057578323454699404,
#  frozenset({'Sulphates_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.07578323454699407,
#  frozenset({'FixedAcidity_bins_High',
#             'Sulphates_bins_High'}): 0.06879762912785775,
#  frozenset({'ResidualSugar_bins_Low',
#             'Sulphates_bins_High'}): 0.06181202370872142,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Sulphates_bins_High'}): 0.07578323454699407,
#  frozenset({'Sulphates_bins_High', 'pH_bins_Low'}): 0.06795088907705335,
#  frozenset({'Sulphates_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.05990685859441151,
#  frozenset({'CitricAcid_bins_High',
#             'Sulphates_bins_High'}): 0.08573243014394581,
#  frozenset({'Density_bins_Low', 'Quality_bins_Bad'}): 0.04826418289585097,
#  frozenset({'Chlorides_bins_Low', 'Quality_bins_Bad'}): 0.06731583403895004,
#  frozenset({'Alcohol_bins_High', 'Quality_bins_Bad'}): 0.018839966130397966,
#  frozenset({'Quality_bins_Bad',
#             'TotalSulfurDioxide_bins_Low'}): 0.0829805249788315,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Bad'}): 0.12044877222692633,
#  frozenset({'Quality_bins_Bad',
#             'ResidualSugar_bins_Low'}): 0.08530906011854361,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Bad'}): 0.13103302286198137,
#  frozenset({'Quality_bins_Bad', 'pH_bins_Low'}): 0.11875529212531753,
#  frozenset({'Quality_bins_Bad',
#             'VolatileAcidity_bins_MidHigh'}): 0.09822184589331075,
#  frozenset({'CitricAcid_bins_High', 'Quality_bins_Bad'}): 0.12193056731583404,
#  frozenset({'Chlorides_bins_Low', 'Density_bins_Low'}): 0.2180355630821338,
#  frozenset({'Alcohol_bins_High', 'Density_bins_Low'}): 0.1994072819644369,
#  frozenset({'Density_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.1896697713801863,
#  frozenset({'Density_bins_Low',
#             'FixedAcidity_bins_High'}): 0.07408975444538526,
#  frozenset({'Density_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.15431837425910244,
#  frozenset({'Density_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.1452159187129551,
#  frozenset({'Density_bins_Low', 'pH_bins_Low'}): 0.10414902624894158,
#  frozenset({'Density_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.07874682472480948,
#  frozenset({'CitricAcid_bins_High', 'Density_bins_Low'}): 0.09504657070279424,
#  frozenset({'Alcohol_bins_High', 'Chlorides_bins_Low'}): 0.17760372565622354,
#  frozenset({'Chlorides_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.18543607112616428,
#  frozenset({'Chlorides_bins_Low',
#             'FixedAcidity_bins_High'}): 0.10393734123624047,
#  frozenset({'Chlorides_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.1121930567315834,
#  frozenset({'Chlorides_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.15347163420829804,
#  frozenset({'Chlorides_bins_Low', 'pH_bins_Low'}): 0.12425910245554615,
#  frozenset({'Chlorides_bins_Low',
#             'VolatileAcidity_bins_MidHigh'}): 0.09060118543607112,
#  frozenset({'Chlorides_bins_Low', 'CitricAcid_bins_High'}): 0.1085944115156647,
#  frozenset({'Alcohol_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.13611346316680778,
#  frozenset({'Alcohol_bins_High',
#             'FixedAcidity_bins_High'}): 0.05990685859441151,
#  frozenset({'Alcohol_bins_High',
#             'ResidualSugar_bins_Low'}): 0.06435224386113463,
#  frozenset({'Alcohol_bins_High',
#             'FreeSulfurDioxide_bins_Low'}): 0.10182049110922947,
#  frozenset({'Alcohol_bins_High', 'pH_bins_Low'}): 0.07345469940728197,
#  frozenset({'Alcohol_bins_High',
#             'VolatileAcidity_bins_MidHigh'}): 0.06668077900084673,
#  frozenset({'Alcohol_bins_High', 'CitricAcid_bins_High'}): 0.06837425910245555,
#  frozenset({'ResidualSugar_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.12976291278577476,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.20999153259949196,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'pH_bins_Low'}): 0.11939034716342083,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Low'}): 0.12150719729043184,
#  frozenset({'FixedAcidity_bins_High', 'pH_bins_Low'}): 0.17146486028789162,
#  frozenset({'ResidualSugar_bins_Low', 'pH_bins_Low'}): 0.07260795935647756,
#  frozenset({'FreeSulfurDioxide_bins_Low', 'pH_bins_Low'}): 0.12616426756985605,
#  frozenset({'CitricAcid_bins_High',
#             'FreeSulfurDioxide_bins_Low'}): 0.10478408128704488,
#  frozenset({'Quality_bins_Bad',
#             'ResidualSugar_bins_LowMid'}): 0.0556731583403895,
#  frozenset({'Chlorides_bins_Low',
#             'ResidualSugar_bins_LowMid'}): 0.11917866215071973,
#  frozenset({'ResidualSugar_bins_LowMid', 'pH_bins_Mid'}): 0.07938187976291279,
#  frozenset({'ResidualSugar_bins_LowMid',
#             'VolatileAcidity_bins_LowMid'}): 0.0558848433530906,
#  frozenset({'ResidualSugar_bins_LowMid',
#             'TotalSulfurDioxide_bins_Low'}): 0.1130397967823878,
#  frozenset({'FixedAcidity_bins_High',
#             'ResidualSugar_bins_LowMid'}): 0.07049110922946655,
#  frozenset({'Alcohol_bins_LowMid',
#             'ResidualSugar_bins_LowMid'}): 0.04360711261642676,
#  frozenset({'ResidualSugar_bins_LowMid',
#             'Sulphates_bins_MidHigh'}): 0.060118543607112614,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'ResidualSugar_bins_LowMid'}): 0.1104995766299746,
#  frozenset({'Density_bins_Mid',
#             'ResidualSugar_bins_LowMid'}): 0.09292972057578323,
#  frozenset({'CitricAcid_bins_High',
#             'ResidualSugar_bins_LowMid'}): 0.06456392887383573,
#  frozenset({'Quality_bins_Bad', 'pH_bins_Mid'}): 0.12637595258255716,
#  frozenset({'Quality_bins_Bad',
#             'VolatileAcidity_bins_LowMid'}): 0.07260795935647756,
#  frozenset({'Alcohol_bins_LowMid', 'Quality_bins_Bad'}): 0.09314140558848434,
#  frozenset({'Quality_bins_Bad',
#             'Sulphates_bins_MidHigh'}): 0.09589331075359865,
#  frozenset({'Density_bins_Mid', 'Quality_bins_Bad'}): 0.12341236240474174,
#  frozenset({'Chlorides_bins_Low', 'pH_bins_Mid'}): 0.10541913632514818,
#  frozenset({'Chlorides_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.07832345469940728,
#  frozenset({'Alcohol_bins_LowMid', 'Chlorides_bins_Low'}): 0.04826418289585097,
#  frozenset({'Chlorides_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.07599491955969517,
#  frozenset({'Chlorides_bins_Low', 'Density_bins_Mid'}): 0.10309060118543607,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'pH_bins_Mid'}): 0.10033869602032176,
#  frozenset({'Sulphates_bins_MidHigh', 'pH_bins_Mid'}): 0.09843353090601185,
#  frozenset({'FreeSulfurDioxide_bins_Low', 'pH_bins_Mid'}): 0.10584250635055038,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.07324301439458086,
#  frozenset({'Sulphates_bins_MidHigh',
#             'VolatileAcidity_bins_LowMid'}): 0.07239627434377646,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.06837425910245555,
#  frozenset({'Sulphates_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Low'}): 0.07472480948348857,
#  frozenset({'FixedAcidity_bins_High',
#             'Sulphates_bins_MidHigh'}): 0.0838272650296359,
#  frozenset({'Alcohol_bins_LowMid',
#             'Sulphates_bins_MidHigh'}): 0.07006773920406435,
#  frozenset({'Alcohol_bins_LowMid',
#             'FreeSulfurDioxide_bins_Low'}): 0.0817104149026249,
#  frozenset({'CitricAcid_bins_High',
#             'Sulphates_bins_MidHigh'}): 0.09356477561388654,
#  frozenset({'Sulphates_bins_High',
#             'VolatileAcidity_bins_Low'}): 0.07027942421676546,
#  frozenset({'Quality_bins_Bad',
#             'VolatileAcidity_bins_Low'}): 0.05207451312447079,
#  frozenset({'Density_bins_Low',
#             'VolatileAcidity_bins_Low'}): 0.09546994072819644,
#  frozenset({'Alcohol_bins_MidHigh',
#             'VolatileAcidity_bins_Low'}): 0.09314140558848434,
#  frozenset({'VolatileAcidity_bins_Low', 'pH_bins_Mid'}): 0.07662997459779848,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_Low'}): 0.11473327688399661,
#  frozenset({'FixedAcidity_bins_High',
#             'VolatileAcidity_bins_Low'}): 0.09525825571549534,
#  frozenset({'ResidualSugar_bins_Low',
#             'VolatileAcidity_bins_Low'}): 0.10287891617273497,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_Low'}): 0.09525825571549534,
#  frozenset({'CitricAcid_bins_High',
#             'VolatileAcidity_bins_Low'}): 0.09991532599491956,
#  frozenset({'Chlorides_bins_Mid',
#             'VolatileAcidity_bins_Low'}): 0.09652836579170194,
#  frozenset({'Alcohol_bins_MidHigh',
#             'Sulphates_bins_High'}): 0.06160033869602032,
#  frozenset({'Sulphates_bins_High', 'pH_bins_Mid'}): 0.06308213378492802,
#  frozenset({'Chlorides_bins_Mid', 'Sulphates_bins_High'}): 0.08446232006773921,
#  frozenset({'Alcohol_bins_MidHigh', 'Quality_bins_Bad'}): 0.05969517358171041,
#  frozenset({'Chlorides_bins_Mid', 'Quality_bins_Bad'}): 0.1111346316680779,
#  frozenset({'Alcohol_bins_MidHigh', 'Density_bins_Low'}): 0.11473327688399661,
#  frozenset({'Density_bins_Low', 'pH_bins_Mid'}): 0.10520745131244708,
#  frozenset({'Chlorides_bins_Mid', 'Density_bins_Low'}): 0.0867908552074513,
#  frozenset({'Alcohol_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Low'}): 0.10457239627434378,
#  frozenset({'Alcohol_bins_MidHigh',
#             'FreeSulfurDioxide_bins_Low'}): 0.10224386113463167,
#  frozenset({'Chlorides_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.09314140558848434,
#  frozenset({'Chlorides_bins_Mid',
#             'FreeSulfurDioxide_bins_Low'}): 0.09631668077900085,
#  frozenset({'Quality_bins_Good',
#             'VolatileAcidity_bins_Low'}): 0.07535986452159187,
#  frozenset({'Density_bins_Low', 'Quality_bins_Good'}): 0.13420829805249787,
#  frozenset({'Alcohol_bins_High', 'Quality_bins_Good'}): 0.11409822184589331,
#  frozenset({'Quality_bins_Good', 'pH_bins_High'}): 0.09652836579170194,
#  frozenset({'Quality_bins_Good',
#             'TotalSulfurDioxide_bins_Mid'}): 0.08827265029635901,
#  frozenset({'Quality_bins_Good',
#             'Sulphates_bins_MidHigh'}): 0.04826418289585097,
#  frozenset({'Quality_bins_Good',
#             'ResidualSugar_bins_Low'}): 0.0552497883149873,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'Quality_bins_Good'}): 0.0556731583403895,
#  frozenset({'FixedAcidity_bins_Mid',
#             'Quality_bins_Good'}): 0.07176121930567315,
#  frozenset({'CitricAcid_bins_High', 'Quality_bins_Good'}): 0.06371718882303133,
#  frozenset({'Chlorides_bins_Mid', 'Quality_bins_Good'}): 0.05355630821337849,
#  frozenset({'Alcohol_bins_High',
#             'VolatileAcidity_bins_Low'}): 0.04445385266723116,
#  frozenset({'VolatileAcidity_bins_Low', 'pH_bins_High'}): 0.10817104149026249,
#  frozenset({'TotalSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_Low'}): 0.09695173581710415,
#  frozenset({'Sulphates_bins_MidHigh',
#             'VolatileAcidity_bins_Low'}): 0.06689246401354784,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_Low'}): 0.0817104149026249,
#  frozenset({'FixedAcidity_bins_Mid',
#             'VolatileAcidity_bins_Low'}): 0.08721422523285352,
#  frozenset({'Density_bins_Low', 'pH_bins_High'}): 0.12468247248094835,
#  frozenset({'Density_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.1138865368331922,
#  frozenset({'Density_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.07091447925486875,
#  frozenset({'Density_bins_Low',
#             'FreeSulfurDioxide_bins_High'}): 0.05800169348010161,
#  frozenset({'Density_bins_Low', 'FixedAcidity_bins_Mid'}): 0.09631668077900085,
#  frozenset({'Alcohol_bins_High', 'pH_bins_High'}): 0.08869602032176122,
#  frozenset({'Alcohol_bins_High',
#             'TotalSulfurDioxide_bins_Mid'}): 0.07790008467400508,
#  frozenset({'Alcohol_bins_High',
#             'Sulphates_bins_MidHigh'}): 0.03831498729889924,
#  frozenset({'Alcohol_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.03746824724809483,
#  frozenset({'Alcohol_bins_High',
#             'FixedAcidity_bins_Mid'}): 0.07260795935647756,
#  frozenset({'Alcohol_bins_High', 'Chlorides_bins_Mid'}): 0.04381879762912786,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'pH_bins_High'}): 0.08933107535986452,
#  frozenset({'FixedAcidity_bins_Mid', 'pH_bins_High'}): 0.08996613039796783,
#  frozenset({'Chlorides_bins_Mid', 'pH_bins_High'}): 0.10309060118543607,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'TotalSulfurDioxide_bins_Mid'}): 0.09398814563928874,
#  frozenset({'FixedAcidity_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.10499576629974598,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'Sulphates_bins_MidHigh'}): 0.0863674851820491,
#  frozenset({'FixedAcidity_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.0846740050804403,
#  frozenset({'Chlorides_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.08721422523285352,
#  frozenset({'FreeSulfurDioxide_bins_High',
#             'ResidualSugar_bins_Low'}): 0.04276037256562235,
#  frozenset({'FixedAcidity_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.06244707874682472,
#  frozenset({'Sulphates_bins_High',
#             'VolatileAcidity_bins_High'}): 0.0550381033022862,
#  frozenset({'Quality_bins_Bad',
#             'VolatileAcidity_bins_High'}): 0.10541913632514818,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_High'}): 0.07578323454699407,
#  frozenset({'FixedAcidity_bins_High',
#             'VolatileAcidity_bins_High'}): 0.06985605419136325,
#  frozenset({'Alcohol_bins_LowMid',
#             'VolatileAcidity_bins_High'}): 0.04551227773073666,
#  frozenset({'VolatileAcidity_bins_High', 'pH_bins_Low'}): 0.07917019475021168,
#  frozenset({'TotalSulfurDioxide_bins_High',
#             'VolatileAcidity_bins_High'}): 0.08615580016934801,
#  frozenset({'ResidualSugar_bins_High',
#             'VolatileAcidity_bins_High'}): 0.0571549534292972,
#  frozenset({'Density_bins_High',
#             'VolatileAcidity_bins_High'}): 0.07895850973751059,
#  frozenset({'CitricAcid_bins_High',
#             'VolatileAcidity_bins_High'}): 0.06646909398814564,
#  frozenset({'Chlorides_bins_Mid',
#             'VolatileAcidity_bins_High'}): 0.05948348856900931,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Sulphates_bins_High'}): 0.08128704487722269,
#  frozenset({'Alcohol_bins_LowMid',
#             'Sulphates_bins_High'}): 0.06795088907705335,
#  frozenset({'Sulphates_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.0867908552074513,
#  frozenset({'ResidualSugar_bins_High',
#             'Sulphates_bins_High'}): 0.05270956816257409,
#  frozenset({'Density_bins_High', 'Sulphates_bins_High'}): 0.07281964436917866,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Bad'}): 0.0817104149026249,
#  frozenset({'Quality_bins_Bad',
#             'TotalSulfurDioxide_bins_High'}): 0.14796782387806942,
#  frozenset({'Quality_bins_Bad',
#             'ResidualSugar_bins_High'}): 0.09928027095681626,
#  frozenset({'Density_bins_High', 'Quality_bins_Bad'}): 0.15664690939881457,
#  frozenset({'FreeSulfurDioxide_bins_Mid', 'pH_bins_Low'}): 0.10372565622353937,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_High'}): 0.08911939034716342,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'ResidualSugar_bins_High'}): 0.07027942421676546,
#  frozenset({'Density_bins_High',
#             'FreeSulfurDioxide_bins_Mid'}): 0.09716342082980525,
#  frozenset({'FixedAcidity_bins_High',
#             'ResidualSugar_bins_High'}): 0.09928027095681626,
#  frozenset({'Alcohol_bins_LowMid', 'pH_bins_Low'}): 0.0571549534292972,
#  frozenset({'Alcohol_bins_LowMid',
#             'ResidualSugar_bins_High'}): 0.05313293818797629,
#  frozenset({'Chlorides_bins_Low', 'Quality_bins_Good'}): 0.13166807790008467,
#  frozenset({'Alcohol_bins_MidHigh', 'Quality_bins_Good'}): 0.06202370872142252,
#  frozenset({'Quality_bins_Good',
#             'TotalSulfurDioxide_bins_Low'}): 0.09631668077900085,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Good'}): 0.09906858594411516,
#  frozenset({'Chlorides_bins_Low',
#             'VolatileAcidity_bins_Low'}): 0.09398814563928874,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'VolatileAcidity_bins_Low'}): 0.09462320067739204,
#  frozenset({'Density_bins_Low',
#             'FreeSulfurDioxide_bins_Mid'}): 0.13082133784928027,
#  frozenset({'Alcohol_bins_MidHigh',
#             'Chlorides_bins_Low'}): 0.10880609652836579,
#  frozenset({'Chlorides_bins_Low',
#             'FreeSulfurDioxide_bins_Mid'}): 0.13103302286198137,
#  frozenset({'Chlorides_bins_Low', 'pH_bins_High'}): 0.13145639288738356,
#  frozenset({'Chlorides_bins_Low',
#             'FixedAcidity_bins_Mid'}): 0.10478408128704488,
#  frozenset({'Alcohol_bins_MidHigh', 'pH_bins_High'}): 0.08806096528365792,
#  frozenset({'Alcohol_bins_MidHigh',
#             'Sulphates_bins_MidHigh'}): 0.06625740897544453,
#  frozenset({'Alcohol_bins_MidHigh',
#             'FixedAcidity_bins_Mid'}): 0.07154953429297206,
#  frozenset({'FixedAcidity_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.09716342082980525,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.08869602032176122,
#  frozenset({'FixedAcidity_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid'}): 0.1121930567315834,
#  frozenset({'CitricAcid_bins_Low',
#             'VolatileAcidity_bins_High'}): 0.11790855207451312,
#  frozenset({'VolatileAcidity_bins_High', 'pH_bins_Mid'}): 0.0825571549534293,
#  frozenset({'Sulphates_bins_Low',
#             'VolatileAcidity_bins_High'}): 0.06985605419136325,
#  frozenset({'TotalSulfurDioxide_bins_Low',
#             'VolatileAcidity_bins_High'}): 0.08022861981371719,
#  frozenset({'ResidualSugar_bins_Low',
#             'VolatileAcidity_bins_High'}): 0.04466553767993226,
#  frozenset({'FixedAcidity_bins_Low',
#             'VolatileAcidity_bins_High'}): 0.09674005080440305,
#  frozenset({'Density_bins_Mid',
#             'VolatileAcidity_bins_High'}): 0.07049110922946655,
#  frozenset({'Quality_bins_Mid',
#             'VolatileAcidity_bins_High'}): 0.0814987298899238,
#  frozenset({'CitricAcid_bins_Low', 'Sulphates_bins_Low'}): 0.10668924640135478,
#  frozenset({'CitricAcid_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.12468247248094835,
#  frozenset({'CitricAcid_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.07959356477561388,
#  frozenset({'Sulphates_bins_Low',
#             'TotalSulfurDioxide_bins_Low'}): 0.11558001693480102,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Sulphates_bins_Low'}): 0.0859441151566469,
#  frozenset({'ResidualSugar_bins_Low',
#             'Sulphates_bins_Low'}): 0.07091447925486875,
#  frozenset({'FixedAcidity_bins_Low',
#             'Sulphates_bins_Low'}): 0.09546994072819644,
# ...
#             'Sulphates_bins_MidHigh'}): 0.03662150719729043,
#  frozenset({'Density_bins_Mid',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.06392887383573242,
#  frozenset({'Density_bins_Mid',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.05779000846740051,
#  frozenset({'Alcohol_bins_Low',
#             'Density_bins_Mid',
#             'Quality_bins_Mid'}): 0.020956816257408976,
#  frozenset({'Chlorides_bins_High',
#             'CitricAcid_bins_Mid',
#             'Density_bins_Mid'}): 0.029635901778154106,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'FixedAcidity_bins_Low'}): 0.04995766299745978,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Low'}): 0.054614733276883994,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04699407281964437,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'pH_bins_High'}): 0.03683319220999153,
#  frozenset({'CitricAcid_bins_Mid',
#             'Density_bins_Mid',
#             'FixedAcidity_bins_Low'}): 0.0281541066892464,
#  frozenset({'CitricAcid_bins_Mid',
#             'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Low'}): 0.04381879762912786,
#  frozenset({'CitricAcid_bins_Mid',
#             'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04149026248941575,
#  frozenset({'CitricAcid_bins_Mid',
#             'Density_bins_Mid',
#             'pH_bins_High'}): 0.04424216765453006,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid'}): 0.05821337849280271,
#  frozenset({'FixedAcidity_bins_Low',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.04911092294665537,
#  frozenset({'FixedAcidity_bins_Low',
#             'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.04657070279424217,
#  frozenset({'FixedAcidity_bins_Low',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.05948348856900931,
#  frozenset({'FixedAcidity_bins_Low',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.07747671464860288,
#  frozenset({'Alcohol_bins_Low',
#             'FixedAcidity_bins_Low',
#             'Quality_bins_Mid'}): 0.03577476714648603,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.03238780694326842,
#  frozenset({'CitricAcid_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.04022015241320914,
#  frozenset({'CitricAcid_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.03662150719729043,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low'}): 0.04932260795935648,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04847586790855207,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'pH_bins_High'}): 0.05779000846740051,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.05270956816257409,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.04106689246401355,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04339542760372565,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.05165114309906858,
#  frozenset({'Alcohol_bins_Low',
#             'FreeSulfurDioxide_bins_Low',
#             'Quality_bins_Mid'}): 0.01968670618120237,
#  frozenset({'CitricAcid_bins_Mid',
#             'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.029635901778154106,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04847586790855207,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.05165114309906858,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low',
#             'ResidualSugar_bins_Low'}): 0.05038103302286198,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_Low',
#             'Sulphates_bins_MidHigh'}): 0.027307366638441997,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.03683319220999153,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_Low',
#             'pH_bins_High'}): 0.04530059271803556,
#  frozenset({'Alcohol_bins_Low',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_Low'}): 0.008044030482641828,
#  frozenset({'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Mid'}): 0.03683319220999153,
#  frozenset({'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh',
#             'pH_bins_High'}): 0.04043183742591024,
#  frozenset({'Alcohol_bins_Low',
#             'Quality_bins_Mid',
#             'Sulphates_bins_MidHigh'}): 0.03069432684165961,
#  frozenset({'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.04826418289585097,
#  frozenset({'Alcohol_bins_Low',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid'}): 0.026460626587637596,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.03598645215918713,
#  frozenset({'Chlorides_bins_High',
#             'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.04000846740050804,
#  frozenset({'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.04741744284504657,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid'}): 0.03513971210838273,
#  frozenset({'Alcohol_bins_Low',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.02222692633361558,
#  frozenset({'CitricAcid_bins_Mid',
#             'FixedAcidity_bins_Low',
#             'pH_bins_High'}): 0.06096528365791702,
#  frozenset({'CitricAcid_bins_Mid',
#             'FreeSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.04191363251481795,
#  frozenset({'CitricAcid_bins_Mid',
#             'ResidualSugar_bins_Low',
#             'pH_bins_High'}): 0.04043183742591024,
#  frozenset({'CitricAcid_bins_Mid',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.04043183742591024,
#  frozenset({'FixedAcidity_bins_Low',
#             'FreeSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.07324301439458086,
#  frozenset({'FixedAcidity_bins_Low',
#             'ResidualSugar_bins_Low',
#             'pH_bins_High'}): 0.06541066892464013,
#  frozenset({'FixedAcidity_bins_Low',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.06160033869602032,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'ResidualSugar_bins_Low',
#             'pH_bins_High'}): 0.05080440304826418,
#  frozenset({'FreeSulfurDioxide_bins_Low',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.0285774767146486,
#  frozenset({'ResidualSugar_bins_Low',
#             'TotalSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.03556308213378493,
#  frozenset({'Chlorides_bins_High',
#             'CitricAcid_bins_High',
#             'FixedAcidity_bins_High'}): 0.05249788314987299,
#  frozenset({'Alcohol_bins_LowMid',
#             'FixedAcidity_bins_High',
#             'Quality_bins_Mid'}): 0.03916172734970364,
#  frozenset({'Alcohol_bins_LowMid',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.04170194750211685,
#  frozenset({'Alcohol_bins_LowMid',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.026883996613039796,
#  frozenset({'Alcohol_bins_LowMid',
#             'Chlorides_bins_High',
#             'Quality_bins_Mid'}): 0.04445385266723116,
#  frozenset({'Alcohol_bins_LowMid',
#             'Density_bins_Mid',
#             'Quality_bins_Mid'}): 0.057366638441998304,
#  frozenset({'Alcohol_bins_LowMid',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.05038103302286198,
#  frozenset({'Alcohol_bins_LowMid',
#             'CitricAcid_bins_High',
#             'Quality_bins_Mid'}): 0.03577476714648603,
#  frozenset({'Alcohol_bins_LowMid',
#             'Density_bins_Mid',
#             'FixedAcidity_bins_High'}): 0.04403048264182896,
#  frozenset({'Alcohol_bins_LowMid',
#             'Density_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.04000846740050804,
#  frozenset({'Alcohol_bins_LowMid',
#             'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.04043183742591024,
#  frozenset({'Alcohol_bins_LowMid',
#             'Chlorides_bins_High',
#             'Density_bins_Mid'}): 0.04868755292125317,
#  frozenset({'Alcohol_bins_LowMid',
#             'Density_bins_Mid',
#             'pH_bins_High'}): 0.05038103302286198,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.03281117696867062,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.04318374259102455,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_High',
#             'Quality_bins_Mid'}): 0.05207451312447079,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High',
#             'Quality_bins_Mid'}): 0.04889923793395427,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.029212531752751906,
#  frozenset({'CitricAcid_bins_High',
#             'FixedAcidity_bins_High',
#             'Quality_bins_Mid'}): 0.06583403895004233,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High',
#             'ResidualSugar_bins_MidHigh'}): 0.03302286198137172,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_Low'}): 0.04466553767993226,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'FixedAcidity_bins_High'}): 0.03535139712108383,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High',
#             'pH_bins_High'}): 0.023708721422523286,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Mid'}): 0.05228619813717189,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.05440304826418289,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Mid'}): 0.04318374259102455,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.0548264182895851,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.04085520745131245,
#  frozenset({'Density_bins_Mid',
#             'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Mid'}): 0.03450465707027942,
#  frozenset({'Density_bins_Mid',
#             'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.027307366638441997,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Mid',
#             'pH_bins_High'}): 0.02180355630821338,
#  frozenset({'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.03789161727349703,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.02476714648602879,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Low'}): 0.029000846740050806,
#  frozenset({'Chlorides_bins_High',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.03662150719729043,
#  frozenset({'Density_bins_Mid',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.06181202370872142,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh',
#             'pH_bins_High'}): 0.03789161727349703,
#  frozenset({'CitricAcid_bins_High',
#             'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.03789161727349703,
#  frozenset({'Density_bins_Mid',
#             'ResidualSugar_bins_MidHigh',
#             'TotalSulfurDioxide_bins_Low'}): 0.03810330228619814,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'ResidualSugar_bins_MidHigh'}): 0.03154106689246401,
#  frozenset({'Density_bins_Mid',
#             'ResidualSugar_bins_MidHigh',
#             'pH_bins_High'}): 0.03217612193056731,
#  frozenset({'Chlorides_bins_High',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.027307366638441997,
#  frozenset({'Density_bins_Mid',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.04784081287044877,
#  frozenset({'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.05080440304826418,
#  frozenset({'CitricAcid_bins_High',
#             'Quality_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.04233700254022015,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Low'}): 0.03196443691786621,
#  frozenset({'Density_bins_Mid',
#             'TotalSulfurDioxide_bins_Low',
#             'pH_bins_High'}): 0.04022015241320914,
#  frozenset({'Chlorides_bins_High',
#             'CitricAcid_bins_High',
#             'Quality_bins_Mid'}): 0.04593564775613886,
#  frozenset({'CitricAcid_bins_High',
#             'Density_bins_Mid',
#             'Quality_bins_Mid'}): 0.04445385266723116,
#  frozenset({'CitricAcid_bins_High',
#             'Quality_bins_Mid',
#             'pH_bins_High'}): 0.04085520745131245,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.11536833192209991,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.09060118543607112,
#  frozenset({'Chlorides_bins_High',
#             'FreeSulfurDioxide_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.09102455546147332,
#  frozenset({'Density_bins_High',
#             'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.07408975444538526,
#  frozenset({'Density_bins_High',
#             'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.09165961049957663,
#  frozenset({'Chlorides_bins_High',
#             'Density_bins_High',
#             'FixedAcidity_bins_High'}): 0.07578323454699407,
#  frozenset({'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.07535986452159187,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_High',
#             'FreeSulfurDioxide_bins_High'}): 0.04657070279424217,
#  frozenset({'Chlorides_bins_High',
#             'FixedAcidity_bins_High',
#             'TotalSulfurDioxide_bins_High'}): 0.06202370872142252,
#  frozenset({'Quality_bins_Mid',
#             'Sulphates_bins_Low',
#             'VolatileAcidity_bins_LowMid'}): 0.027307366638441997,
#  frozenset({'Quality_bins_Mid',
#             'Sulphates_bins_Low',
#             'pH_bins_Mid'}): 0.04191363251481795,
#  frozenset({'Alcohol_bins_LowMid',
#             'Quality_bins_Mid',
#             'Sulphates_bins_Low'}): 0.023920406435224386,
#  frozenset({'FixedAcidity_bins_High',
#             'Quality_bins_Mid',
#             'Sulphates_bins_Low'}): 0.04233700254022015,
#  frozenset({'Quality_bins_Mid',
#             'ResidualSugar_bins_MidHigh',
#             'Sulphates_bins_Low'}): 0.03598645215918713,
#  frozenset({'Chlorides_bins_High',
#             'Quality_bins_Mid',
#             'Sulphates_bins_Low'}): 0.026037256562235395,
#  ...}

# %%
generateRules(L,suppData, minConf=0.8)

# Remark: the lift results for thos rules are the same.
# Out:
# frozenset({'Alcohol_bins_High'}) --> frozenset({'Density_bins_Low'}) conf: 0.8425760286225402
# frozenset({'ResidualSugar_bins_High'}) --> frozenset({'Density_bins_High'}) conf: 0.8985507246376812
# [(frozenset({'Alcohol_bins_High'}),
#   frozenset({'Density_bins_Low'}),
#   0.8425760286225402),
#  (frozenset({'ResidualSugar_bins_High'}),
#   frozenset({'Density_bins_High'}),
#   0.8985507246376812)]

# %%
# Test:
# we want to see that the rules created by the Apriory algorithm can be found in the previous FP-Growth.

print(FP_rules.iloc[49])
print(FP_rules.iloc[75])

# Test passed.
# Out:
# antecedent    [ResidualSugar_bins_High]
# consequent          [Density_bins_High]
# confidence                     0.898551
# lift                            2.69851
# Name: 49, dtype: object
# antecedent    [Alcohol_bins_High]
# consequent     [Density_bins_Low]
# confidence               0.842576
# lift                      2.52239
# Name: 75, dtype: object

# %% [markdown]
# # Compering the algorithms:
# We can see both algorithms produced the same rules, the Apriori implementation gave us less rules, but it can be altered in order to give all the upper level frequents.
# On the results found, the lift was similar, as expected.
# We can see that the Apriory is focused on finding the items sets, while the FP-Growth give us straight forword the rules without further calculation needed in the apriori.
# The FP-growh is also aranged is a tree structure, which help us to better understand the structure of the data.
